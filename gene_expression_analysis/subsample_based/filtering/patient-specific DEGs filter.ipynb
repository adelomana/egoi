# %% [markdown]
# # info
# This script generates a file with filtered DEGs derived from patient-specific DEG calling.

# %% [markdown]
# Filters are:
# 1. Filter on P < 0.05 and Q < 0.1 for DESeq2; Q < 0.05 in sleuth.
# 2. Filter out genes that in the comparison do not cross the 2 TPM barrier.
# 3. Discrete abs log2 FC > 1
#
# Coherent DEGs are the ones that pass all three filters in n-1 patients.

# %%
import pandas, os, numpy

# %% [markdown]
# # 0. user-defined variables

# %%
expression_threshold = 2
discrete_fc_threshold = 1
noise_threshold = 1/2

# %%
hypotheses = ['hypothesis_A', 'hypothesis_B', 'hypothesis_C', 'hypothesis_D', 'hypothesis_E']
trends = ['up', 'down']

# %%
metadata_file = '/home/adrian/projects/hegoi/metadata/hegoi metadata - hypotheses formatted for filter.tsv'
tpm_file = '/home/adrian/projects/hegoi/results/tpm/DESeq2_TPM_values.tsv'
deseq2_folder = '/home/adrian/projects/hegoi/results/subsamples/DESeq2/'

output_dir = '/home/adrian/projects/hegoi/results/subsamples/DEG_filtered/'
filtered_DEGs_file = '/home/adrian/projects/hegoi/results/subsamples/DEG_filtered/filtered_DEGs.tsv'

# %% [markdown]
# # 1. read input files

# %% [markdown]
# ## 1.1 read expression data

# %%
expression = pandas.read_csv(tpm_file, sep='\t', index_col=0)
sample_names = expression.columns.to_list()

print(sample_names)
expression.head()
# Out:
# ['Lam153', 'Lami154', 'Lami46', 'Lami94', 'LamiP109', 'LamiP153', 'LamiP154', 'LamiP176', 'LamiPi46', 'LamiPi94', 'Osci109', 'Osci153', 'Osci154', 'Osci46', 'OsciP109', 'OsciP153', 'OsciP154', 'OsciP175', 'OsciP178', 'OsciPi46', 'Stat109', 'Stat153', 'Stat154', 'Stat176', 'Stat46', 'Stat94']
#                     Lam153    Lami154      Lami46      Lami94    LamiP109  \
# ENSG00000000003  24.240953  20.242011   22.919919   15.438227   18.098457
# ENSG00000000005   0.062960   0.000000    0.000000    0.000000    0.000000
# ENSG00000000419  59.982918  62.984443  120.871295  138.059565  115.707396
# ENSG00000000457   4.680221   3.684855    1.989328    3.244174    4.417648
# ENSG00000000460   1.982690   1.344508    1.422365    1.667403    0.570064
#
#                   LamiP153    LamiP154    LamiP176    LamiPi46    LamiPi94  \
# ENSG00000000003  29.000777   14.784503   11.903633   26.217884   18.455471
# ENSG00000000005   0.000000    0.000000    0.000000    0.000000    0.000000
# ENSG00000000419  84.892000  172.643218  147.901176  145.183145  135.750959
# ENSG00000000457   2.189278    6.217483    3.998143    4.786793    2.949599
# ENSG00000000460   2.856698    0.416009    0.000000    1.310974    1.812507
#
#                  ...   OsciP154    OsciP175   OsciP178    OsciPi46    Stat109  \
# ENSG00000000003  ...  38.756393   15.976121  21.649331   28.426877  29.688663
# ENSG00000000005  ...   0.000000    0.000000   0.000000    0.000000   0.000000
# ENSG00000000419  ...  98.473591  161.024012  86.023654  115.321222  64.464680
# ENSG00000000457  ...   3.012943    1.024624   2.255165    2.967113   1.825466
# ENSG00000000460  ...   5.510741    3.805323   1.489214    0.957885   4.467578
#
#                    Stat153    Stat154    Stat176     Stat46     Stat94
# ENSG00000000003  29.207002  28.989493  28.832380  34.600089  27.971771
# ENSG00000000005   0.000000   0.000000   0.013958   0.000000   0.139231
# ENSG00000000419  81.686544  84.388415  88.740844  81.992995  97.987628
# ENSG00000000457   2.371161   3.513856   2.617785   2.546863   2.668982
# ENSG00000000460   5.425887   7.680067   4.002537   3.650609   4.056977
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 1.2. read metadata

# %%
metadata = pandas.read_csv(metadata_file, sep='\t', index_col=0)
metadata.head()
# Out:
#               patient  sampleA  sampleB
# hypothesis
# hypothesis_A       46   Stat46   Lami46
# hypothesis_A      153  Stat153   Lam153
# hypothesis_A      154  Stat154  Lami154
# hypothesis_A       94   Stat94   Lami94
# hypothesis_B       46   Lami46   Osci46

# %% [markdown]
# # 2. iterate over hypotheses and patients

# %%
### 1. iterate over hypothesis
for hypothesis in hypotheses:
    
    ### 2. iterate over trends
    for trend in trends:
        
        print('working with {} {}'.format(hypothesis, trend))
        box = {}; predf = {}
        
        ### 3. gather patients
        elements = os.listdir(deseq2_folder)
        working_elements = [element for element in elements if hypothesis in element and trend in element]
        number_of_patients = len(working_elements)
        
        print(working_elements, len(working_elements))

        ### 4. gather information
        
        ## 4.1. get adjusted P values and log2FC
        for working_element in working_elements:
            
            ## 4.1. define reference and sample expression labels
            patient = int(working_element.split('_')[2])
            ref_label = None; sam_label = None
            ref_label = metadata[metadata['patient'] == patient].loc[hypothesis]['sampleA']
            sam_label = metadata[metadata['patient'] == patient].loc[hypothesis]['sampleB']
            
            ## 4.2. get adjusted P values and log2FC
            f = open(deseq2_folder + working_element, 'r')
            next(f)
            for line in f:
                v = line.split('\t')
                ensembl = v[0]
                log2FC = float(v[2])
                adjusted = float(v[6])
                annotation = (v[7], v[8].split(' [')[0], v[9].replace('\n', ''))
                                
                if ensembl not in box:
                    box[ensembl]=[[log2FC], [adjusted], [], [], [], annotation]
                else:
                    box[ensembl][0].append(log2FC); box[ensembl][1].append(adjusted)   

                ### 4.3. get reference and sample expression   
                tpm_ref = expression[ref_label].loc[ensembl]
                tpm_sam = expression[sam_label].loc[ensembl]

                num = numpy.around(tpm_sam) + 1
                den = numpy.around(tpm_ref) + 1
                fc = num/den
                abs_discrete_log2FC = numpy.abs(numpy.log2(fc))

                box[ensembl][2].append(tpm_ref)
                box[ensembl][3].append(tpm_sam)
                box[ensembl][4].append(abs_discrete_log2FC)
                
            # late file closure
            f.close()
        
        ### 5. perform filters
        calls = len(box.keys())
        consistency_filter_count = 0
        low_expression_filter_count = 0
        discrete_filter_count = 0
        noise_filter_count = 0
        
        for gene in box:
            
            selected = True
                                    
            ## F1 | consistency across patients, DEG called at least n - 1
            if len(box[gene][0]) < number_of_patients - 1:
                selected = False
                consistency_filter_count = consistency_filter_count + 1
                
            ## F2 | filter on low expression
            if selected == True:
                a = numpy.median(box[gene][2])
                b = numpy.median(box[gene][3])
                top = numpy.max([a, b])
                if top < expression_threshold:
                    selected = False
                    low_expression_filter_count = low_expression_filter_count + 1
            
            ## F3 | filter on abs discrete log2 FC
            if selected == True:
                if numpy.median(box[gene][4]) < discrete_fc_threshold:
                    selected = False
                    discrete_filter_count = discrete_filter_count + 1
                    
            ## F4 | filter on noise 
            if selected == True:
                
                a = box[gene][2]; b = box[gene][3]
                a = numpy.around(a); b = numpy.around(b)
                
                if numpy.mean(a) > 2:
                    sem_ref = numpy.std(a) / numpy.sqrt(len(a))
                    rsem_ref = sem_ref / numpy.mean(a)
                else:
                    rsem_ref = 0
                
                if numpy.mean(b) > 2:
                    sem_sam = numpy.std(b) / numpy.sqrt(len(b))
                    rsem_sam = sem_sam / numpy.mean(b)
                else:
                    rsem_sam = 0
                
                noise = numpy.max([rsem_ref, rsem_sam])
                
                if noise > noise_threshold:
                    selected = False
                    noise_filter_count = noise_filter_count + 1 
                    print('\t', 'WARNING: removing due to noise {}'.format(noise))
                    print('\t', gene, box[gene][-1])
                    print('\t', 'ref', a, rsem_ref)
                    print('\t', 'sam', b, rsem_sam)
                    print()
            ###
            if selected == True:
                predf[gene] = []
                predf[gene].append(numpy.median(box[gene][0])) # log2FC
                predf[gene].append(numpy.median(box[gene][1])) # adjusted P
                predf[gene].append(numpy.median(box[gene][2])) # ref
                predf[gene].append(numpy.median(box[gene][3])) # sam
                predf[gene].append(numpy.median(box[gene][4])) # abs discrete log2FC
                
                # checking that FCs ave the same sign across all patients
                same_sign = not min(box[gene][0]) < 0 < max(box[gene][0])
                if same_sign == False:
                    raise ValueError('ERROR: Not all patients have the same trend.')
                
                for ann in box[gene][5]:
                    predf[gene].append(ann)
                    
            if gene == 'ENSG00000187957':
                for element in box[gene]:
                    print(element)
                    
        ### final print        
        print('DEGs union across patients \t {}'.format(calls))
        print('working set after n - 1 consistency \t {}'.format(calls-consistency_filter_count))
        print('working set after low-expression filter \t {}'.format(calls-consistency_filter_count-low_expression_filter_count))
        print('working set after discrete FC filter \t {}'.format(calls-consistency_filter_count-low_expression_filter_count-discrete_filter_count))
        print('working set after noise filter \t {}'.format(calls-consistency_filter_count-low_expression_filter_count-discrete_filter_count-noise_filter_count))
        
        ### generate a dataframe and store
        outputfile = output_dir + 'annotateddf_' + hypothesis + '_' + trend + '.tsv'
        
        df = pandas.DataFrame.from_dict(predf)
        dft = df.transpose()
        print('about to store a dataframe of shape {}'.format(dft.shape))
        
        dft.columns = ['log2FC', 'adjusted P', 'Reference expression (TPM)', 'Sample expression (TPM)', 'Discrete abs(log2FC)', 'Biotype', 'Description', 'Symbol']
        ordered_columns = ['Biotype', 'Symbol', 'Description', 'log2FC', 'adjusted P', 'Reference expression (TPM)', 'Sample expression (TPM)', 'Discrete abs(log2FC)']
        dft = dft[ordered_columns]
        dft.index.name = 'ENSEMBL'
        dft.sort_values(by='Discrete abs(log2FC)', axis=0, inplace=True, ascending=False)
        # remove duplicates
        dft.drop_duplicates(subset=['Symbol'], keep='first', inplace=True)
        
        dft.to_csv(outputfile)
        
        print('--------------------------------------')
# Out:
# working with hypothesis_A up
# ['hypothesis_A_154_up.tsv', 'hypothesis_A_46_up.tsv', 'hypothesis_A_94_up.tsv', 'hypothesis_A_153_up.tsv'] 4
# 	 WARNING: removing due to noise 0.6356594003488406
# 	 ENSG00000115461 ('protein_coding', 'insulin like growth factor binding protein 5', 'IGFBP5')
# 	 ref [0. 0. 0. 1.] 0
# 	 sam [423.   7.   4. 105.] 0.6356594003488406
#
# 	 WARNING: removing due to noise 0.5715217447490105
# 	 ENSG00000187922 ('protein_coding', 'lipocalin 10', 'LCN10')
# 	 ref [0. 0. 0. 0.] 0
# 	 sam [130.   1.   3.  49.] 0.5715217447490105
#
# 	 WARNING: removing due to noise 0.5411718220815724
# 	 ENSG00000198643 ('protein_coding', 'family with sequence similarity 3 member D', 'FAM3D')
# 	 ref [0. 0. 0.] 0
# 	 sam [41.  1. 12.] 0.5411718220815724
#
# 	 WARNING: removing due to noise 0.6214059902060192
# 	 ENSG00000159167 ('protein_coding', 'stanniocalcin 1', 'STC1')
# 	 ref [1. 1. 1. 0.] 0
# 	 sam [85.  5.  7. 11.] 0.6214059902060192
#
# [1.95227257407968, 4.84352418008654, 2.27817707497821, 2.31620311503187]
# [0.0144980013881868, 3.13732002297953e-06, 0.00219315819912681, 0.00322259628009699]
# [0.6378924, 0.04994954, 0.4161218, 0.602106]
# [2.31244, 1.031262, 1.981396, 3.165025]
# [0.5849625007211562, 1.0, 1.584962500721156, 1.0]
# ('protein_coding', 'delta/notch like EGF repeat containing', 'DNER')
# 	 WARNING: removing due to noise 0.6137636568827022
# 	 ENSG00000197632 ('protein_coding', 'serpin family B member 2', 'SERPINB2')
# 	 ref [0. 1. 0.] 0
# 	 sam [15. 88.  3.] 0.6137636568827022
#
# DEGs union across patients 	 2290
# working set after n - 1 consistency 	 188
# working set after low-expression filter 	 178
# working set after discrete FC filter 	 178
# working set after noise filter 	 173
# about to store a dataframe of shape (173, 8)
# --------------------------------------
# working with hypothesis_A down
# ['hypothesis_A_154_down.tsv', 'hypothesis_A_46_down.tsv', 'hypothesis_A_94_down.tsv', 'hypothesis_A_153_down.tsv'] 4
# 	 WARNING: removing due to noise 0.697614984548545
# 	 ENSG00000178882 ('protein_coding', 'refilin A', 'RFLNA')
# 	 ref [18. 26.  5.] 0.3058956075634982
# 	 sam [0. 9. 1.] 0.697614984548545
#
# 	 WARNING: removing due to noise 0.6571287406727709
# 	 ENSG00000170323 ('protein_coding', 'fatty acid binding protein 4', 'FABP4')
# 	 ref [ 45.  62. 101.  38.] 0.19852220239145982
# 	 sam [ 1. 18.  1.  2.] 0.6571287406727709
#
# 	 WARNING: removing due to noise 0.5034040503016264
# 	 ENSG00000163739 ('protein_coding', 'C-X-C motif chemokine ligand 1', 'CXCL1')
# 	 ref [369. 966. 458.] 0.2540339620380326
# 	 sam [ 11. 197.  62.] 0.5034040503016264
#
# 	 WARNING: removing due to noise 0.6093413965251636
# 	 ENSG00000133110 ('protein_coding', 'periostin', 'POSTN')
# 	 ref [1198. 3440.  881. 2108.] 0.2604452016784179
# 	 sam [ 46.  49.   8. 353.] 0.6093413965251636
#
# 	 WARNING: removing due to noise 0.6319062870042959
# 	 ENSG00000187513 ('protein_coding', 'gap junction protein alpha 4', 'GJA4')
# 	 ref [ 67. 179. 241. 110.] 0.22227464877679073
# 	 sam [ 3. 19.  0.  2.] 0.6319062870042959
#
# 	 WARNING: removing due to noise 0.5351001587841251
# 	 ENSG00000134363 ('protein_coding', 'follistatin', 'FST')
# 	 ref [16. 44.  9. 18.] 0.3051394012059376
# 	 sam [ 1. 12.  3.  1.] 0.5351001587841251
#
# 	 WARNING: removing due to noise 0.5759050847723663
# 	 ENSG00000139329 ('protein_coding', 'lumican', 'LUM')
# 	 ref [ 3.  1. 16.] 0.5759050847723663
# 	 sam [0. 0. 5.] 0
#
# 	 WARNING: removing due to noise 0.6295798667988843
# 	 ENSG00000137959 ('protein_coding', 'interferon induced protein 44 like', 'IFI44L')
# 	 ref [ 7.  3. 55.] 0.6295798667988843
# 	 sam [1. 0. 3.] 0
#
# 	 WARNING: removing due to noise 0.6692657668420422
# 	 ENSG00000265107 ('protein_coding', 'gap junction protein alpha 5', 'GJA5')
# 	 ref [  3. 125.  18.] 0.6444425391579529
# 	 sam [1. 7. 0.] 0.6692657668420422
#
# 	 WARNING: removing due to noise 0.5229763603684907
# 	 ENSG00000168542 ('protein_coding', 'collagen type III alpha 1 chain', 'COL3A1')
# 	 ref [ 29.  22. 113.] 0.4366750600510555
# 	 sam [ 9.  1. 29.] 0.5229763603684907
#
# 	 WARNING: removing due to noise 0.6152009608430583
# 	 ENSG00000285438 ('protein_coding', 'SRY-box 7', 'SOX7')
# 	 ref [ 6. 21. 51.] 0.415432096051786
# 	 sam [ 1.  3. 20.] 0.6152009608430583
#
# DEGs union across patients 	 2831
# working set after n - 1 consistency 	 361
# working set after low-expression filter 	 318
# working set after discrete FC filter 	 318
# working set after noise filter 	 307
# about to store a dataframe of shape (307, 8)
# --------------------------------------
# working with hypothesis_B up
# ['hypothesis_B_154_up.tsv', 'hypothesis_B_46_up.tsv', 'hypothesis_B_153_up.tsv'] 3
# 	 WARNING: removing due to noise 0.6280742930213279
# 	 ENSG00000091986 ('protein_coding', 'coiled-coil domain containing 80', 'CCDC80')
# 	 ref [ 1.  1. 11.] 0.6280742930213279
# 	 sam [ 9.  7. 48.] 0.5107885549977278
#
# 	 WARNING: removing due to noise 0.6060915267313264
# 	 ENSG00000169429 ('protein_coding', 'C-X-C motif chemokine ligand 8', 'CXCL8')
# 	 ref [  8. 104.] 0.6060915267313264
# 	 sam [ 49. 216.] 0.4456106885213337
#
# 	 WARNING: removing due to noise 0.5568051909067913
# 	 ENSG00000133110 ('protein_coding', 'periostin', 'POSTN')
# 	 ref [ 46.  49. 353.] 0.5568051909067913
# 	 sam [ 267.  281. 1190.] 0.4303661571281814
#
# 	 WARNING: removing due to noise 0.5303300858899106
# 	 ENSG00000265107 ('protein_coding', 'gap junction protein alpha 5', 'GJA5')
# 	 ref [1. 7.] 0.5303300858899106
# 	 sam [ 5. 30.] 0.5050762722761053
#
# 	 WARNING: removing due to noise 0.6239177481057772
# 	 ENSG00000047617 ('protein_coding', 'anoctamin 2', 'ANO2')
# 	 ref [4. 0.] 0
# 	 sam [16.  1.] 0.6239177481057772
#
# 	 WARNING: removing due to noise 0.5303300858899106
# 	 ENSG00000150594 ('protein_coding', 'adrenoceptor alpha 2A', 'ADRA2A')
# 	 ref [2. 0.] 0
# 	 sam [7. 1.] 0.5303300858899106
#
# 	 WARNING: removing due to noise 0.5303300858899106
# 	 ENSG00000172260 ('protein_coding', 'neuronal growth regulator 1', 'NEGR1')
# 	 ref [0. 0.] 0
# 	 sam [7. 1.] 0.5303300858899106
#
# 	 WARNING: removing due to noise 0.7071067811865475
# 	 ENSG00000140092 ('protein_coding', 'fibulin 5', 'FBLN5')
# 	 ref [0. 5.] 0.7071067811865475
# 	 sam [ 2. 16.] 0.5499719409228703
#
# 	 WARNING: removing due to noise 0.5050762722761053
# 	 ENSG00000128606 ('protein_coding', 'leucine rich repeat containing 17', 'LRRC17')
# 	 ref [0. 1.] 0
# 	 sam [1. 6.] 0.5050762722761053
#
# 	 WARNING: removing due to noise 0.656599153958937
# 	 ENSG00000277236 ('protein_coding', 'C-C motif chemokine ligand 14', 'CCL14')
# 	 ref [0. 0.] 0
# 	 sam [ 2. 54.] 0.656599153958937
#
# DEGs union across patients 	 1251
# working set after n - 1 consistency 	 237
# working set after low-expression filter 	 208
# working set after discrete FC filter 	 206
# working set after noise filter 	 196
# about to store a dataframe of shape (196, 8)
# --------------------------------------
# working with hypothesis_B down
# ['hypothesis_B_46_down.tsv', 'hypothesis_B_154_down.tsv', 'hypothesis_B_153_down.tsv'] 3
# 	 WARNING: removing due to noise 0.5411718220815724
# 	 ENSG00000198643 ('protein_coding', 'family with sequence similarity 3 member D', 'FAM3D')
# 	 ref [ 1. 41. 12.] 0.5411718220815724
# 	 sam [0. 1. 0.] 0
#
# 	 WARNING: removing due to noise 0.5087602374750728
# 	 ENSG00000267206 ('protein_coding', 'lipocalin 6', 'LCN6')
# 	 ref [ 21. 367. 111.] 0.5087602374750728
# 	 sam [1. 1. 3.] 0
#
# 	 WARNING: removing due to noise 0.5195887333176439
# 	 ENSG00000095713 ('protein_coding', 'cartilage acidic protein 1', 'CRTAC1')
# 	 ref [ 3. 40. 22.] 0.402555936549546
# 	 sam [0. 8. 3.] 0.5195887333176439
#
# 	 WARNING: removing due to noise 0.5122571692103561
# 	 ENSG00000187922 ('protein_coding', 'lipocalin 10', 'LCN10')
# 	 ref [  1. 130.  49.] 0.5122571692103561
# 	 sam [0. 0. 0.] 0
#
# 	 WARNING: removing due to noise 0.6331072343181879
# 	 ENSG00000196154 ('protein_coding', 'S100 calcium binding protein A4', 'S100A4')
# 	 ref [  9. 163.] 0.6331072343181879
# 	 sam [2. 7.] 0.39283710065919303
#
# 	 WARNING: removing due to noise 0.5748831023947797
# 	 ENSG00000115461 ('protein_coding', 'insulin like growth factor binding protein 5', 'IGFBP5')
# 	 ref [  7. 423. 105.] 0.5748831023947797
# 	 sam [2. 4. 3.] 0.15713484026367724
#
# 	 WARNING: removing due to noise 0.5303300858899106
# 	 ENSG00000138061 ('protein_coding', 'cytochrome P450 family 1 subfamily B member 1', 'CYP1B1')
# 	 ref [39. 65.] 0.17677669529663687
# 	 sam [1. 7.] 0.5303300858899106
#
# 	 WARNING: removing due to noise 0.5450614771646304
# 	 ENSG00000159167 ('protein_coding', 'stanniocalcin 1', 'STC1')
# 	 ref [85. 11.] 0.5450614771646304
# 	 sam [2. 1.] 0
#
# 	 WARNING: removing due to noise 0.565685424949238
# 	 ENSG00000132470 ('protein_coding', 'integrin subunit beta 4', 'ITGB4')
# 	 ref [151. 102.] 0.1369495346962088
# 	 sam [9. 1.] 0.565685424949238
#
# DEGs union across patients 	 1348
# working set after n - 1 consistency 	 340
# working set after low-expression filter 	 326
# working set after discrete FC filter 	 325
# working set after noise filter 	 316
# about to store a dataframe of shape (316, 8)
# --------------------------------------
# working with hypothesis_C up
# ['hypothesis_C_46_up.tsv', 'hypothesis_C_154_up.tsv', 'hypothesis_C_153_up.tsv', 'hypothesis_C_109_up.tsv'] 4
# 	 WARNING: removing due to noise 0.5665577237325317
# 	 ENSG00000115457 ('protein_coding', 'insulin like growth factor binding protein 2', 'IGFBP2')
# 	 ref [0. 2. 7.] 0.5665577237325317
# 	 sam [ 0. 13. 34.] 0.516222422271712
#
# 	 WARNING: removing due to noise 0.5400617248673217
# 	 ENSG00000273622 ('protein_coding', 'CDC42 effector protein 5', 'CDC42EP5')
# 	 ref [6. 2. 0.] 0.5400617248673217
# 	 sam [75. 38. 34.] 0.21747438589313992
#
# 	 WARNING: removing due to noise 0.5084322977157767
# 	 ENSG00000100321 ('protein_coding', 'synaptogyrin 1', 'SYNGR1')
# 	 ref [5. 0. 2.] 0.5084322977157767
# 	 sam [15.  3.  9.] 0.31426968052735443
#
# 	 WARNING: removing due to noise 0.7412686197773832
# 	 ENSG00000276409 ('protein_coding', 'C-C motif chemokine ligand 14', 'CCL14')
# 	 ref [ 0. 15.  1.] 0.7412686197773832
# 	 sam [217. 116. 130.] 0.16714141683225217
#
# DEGs union across patients 	 5038
# working set after n - 1 consistency 	 164
# working set after low-expression filter 	 91
# working set after discrete FC filter 	 89
# working set after noise filter 	 85
# about to store a dataframe of shape (85, 8)
# --------------------------------------
# working with hypothesis_C down
# ['hypothesis_C_46_down.tsv', 'hypothesis_C_154_down.tsv', 'hypothesis_C_153_down.tsv', 'hypothesis_C_109_down.tsv'] 4
# 	 WARNING: removing due to noise 0.6075738683564674
# 	 ENSG00000267206 ('protein_coding', 'lipocalin 6', 'LCN6')
# 	 ref [ 34.  47. 127.] 0.34241661332486173
# 	 sam [0. 9. 2.] 0.6075738683564674
#
# 	 WARNING: removing due to noise 0.5212165257037297
# 	 ENSG00000111012 ('protein_coding', 'cytochrome P450 family 27 subfamily B member 1', 'CYP27B1')
# 	 ref [ 2. 30.  8.] 0.5212165257037297
# 	 sam [0. 0. 0.] 0
#
# 	 WARNING: removing due to noise 0.5366269111911884
# 	 ENSG00000123496 ('protein_coding', 'interleukin 13 receptor subunit alpha 2', 'IL13RA2')
# 	 ref [ 46. 111. 130.] 0.21705573910766432
# 	 sam [10.  1.  2.] 0.5366269111911884
#
# 	 WARNING: removing due to noise 0.7041346661211583
# 	 ENSG00000115461 ('protein_coding', 'insulin like growth factor binding protein 5', 'IGFBP5')
# 	 ref [ 5. 99.  5.] 0.7041346661211583
# 	 sam [2. 1. 1.] 0
#
# [-2.11752262102619, -3.01746529702634]
# [0.000312576817348808, 6.17626587093327e-07]
# [3.42353, 2.547609]
# [0.762244, 0.3271343]
# [1.0, 2.0]
# ('protein_coding', 'delta/notch like EGF repeat containing', 'DNER')
# DEGs union across patients 	 4359
# working set after n - 1 consistency 	 64
# working set after low-expression filter 	 46
# working set after discrete FC filter 	 46
# working set after noise filter 	 42
# about to store a dataframe of shape (42, 8)
# --------------------------------------
# working with hypothesis_D up
# ['hypothesis_D_153_up.tsv', 'hypothesis_D_94_up.tsv', 'hypothesis_D_46_up.tsv', 'hypothesis_D_154_up.tsv'] 4
# DEGs union across patients 	 3677
# working set after n - 1 consistency 	 17
# working set after low-expression filter 	 5
# working set after discrete FC filter 	 5
# working set after noise filter 	 5
# about to store a dataframe of shape (5, 8)
# --------------------------------------
# working with hypothesis_D down
# ['hypothesis_D_94_down.tsv', 'hypothesis_D_154_down.tsv', 'hypothesis_D_153_down.tsv', 'hypothesis_D_46_down.tsv'] 4
# 	 WARNING: removing due to noise 0.5418955560352877
# 	 ENSG00000197142 ('protein_coding', 'acyl-CoA synthetase long chain family member 5', 'ACSL5')
# 	 ref [ 9. 32.  1.] 0.5418955560352877
# 	 sam [3. 9. 0.] 0.5400617248673217
#
# 	 WARNING: removing due to noise 0.8164965809277261
# 	 ENSG00000164530 ('protein_coding', 'peptidase inhibitor 16', 'PI16')
# 	 ref [113.  60.   0.] 0.46216273716646816
# 	 sam [ 0. 12.  0.] 0.8164965809277261
#
# DEGs union across patients 	 4532
# working set after n - 1 consistency 	 45
# working set after low-expression filter 	 19
# working set after discrete FC filter 	 19
# working set after noise filter 	 17
# about to store a dataframe of shape (17, 8)
# --------------------------------------
# working with hypothesis_E up
# ['hypothesis_E_154_up.tsv', 'hypothesis_E_109_up.tsv', 'hypothesis_E_46_up.tsv', 'hypothesis_E_153_up.tsv'] 4
# DEGs union across patients 	 1252
# working set after n - 1 consistency 	 2
# working set after low-expression filter 	 2
# working set after discrete FC filter 	 2
# working set after noise filter 	 2
# about to store a dataframe of shape (2, 8)
# --------------------------------------
# working with hypothesis_E down
# ['hypothesis_E_46_down.tsv', 'hypothesis_E_109_down.tsv', 'hypothesis_E_153_down.tsv', 'hypothesis_E_154_down.tsv'] 4
# DEGs union across patients 	 1491
# working set after n - 1 consistency 	 13
# working set after low-expression filter 	 9
# working set after discrete FC filter 	 9
# working set after noise filter 	 9
# about to store a dataframe of shape (9, 8)
# --------------------------------------
